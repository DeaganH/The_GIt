# %%
# %matplotlib inline
import re
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.multiclass import OneVsRestClassifier
import nltk
from nltk.corpus import stopwords
stop_words = set(stopwords.words('french'))
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.pipeline import Pipeline
import seaborn as sns

# %%
df = pd.read_csv('french_lexicon.csv')

# %%
df.head()
# Out:
#    id             word  polarity  joy  fear  sadness  anger  surprise  disgust
# 0   1  à ce endroit là  positive    0     0        0      0         0        0
# 1   2        à le hâte  negative    0     1        0      0         1        0
# 2   3           à part  negative    0     0        1      0         0        0
# 3   4            à pic  negative    0     1        0      0         0        0
# 4   5       à rallonge  negative    0     0        1      0         0        0

# %%
df.drop(['polarity'], axis = 1, inplace = True)

# %%
df_new = df.drop(['id', 'word'], axis=1)
counts = []
categories = list(df_new.columns.values)
for i in categories:
    counts.append((i, df[i].sum()))
df_stats = pd.DataFrame(counts, columns=['Emotion', 'no. sentences'])
df_stats
# Out:
#     Emotion  no. sentences
# 0       joy            521
# 1      fear           3199
# 2   sadness           2512
# 3     anger           2103
# 4  surprise           1182
# 5   disgust           2013

# %%
pd.set_option('display.max_colwidth', -1)
pd.DataFrame(df['word']).head()
# Out:
#               word
# 0  à ce endroit là
# 1  à le hâte
# 2  à part
# 3  à pic
# 4  à rallonge

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub('\W', ' ', text)
    text = re.sub('\w*\d\w*', ' ', text) 
    text = re.sub('\s+', ' ', text)
    text = re.sub(r"\à", "", text)
    text = text.strip(' ')
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    return text

# %%
df['word'] = df['word'].map(lambda com : clean_text(com))

# %%
df['word'][0:10]
# Out:
# 0    ce endroit
# 1    le hâte
# 2    part
# 3    pic
# 4    rallonge
# 5    abasourdir
# 6    ablation
# 7    abominable
# 8    abrupt
# 9    absent
# Name: word, dtype: object

# %%
train, test = train_test_split(df, test_size=0.20, random_state=1, shuffle=True)

# %%
X_train = train.word
X_test = test.word
print(X_train.shape)
print(X_test.shape)
# Out:
# (11301,)
# (2826,)

# %%
categories = ['joy', 'fear', 'sadness','anger', 'surprise', 'disgust']

# %%
# Define a pipeline combining a text feature extractor with multi lable classifier
SVC_pipeline = Pipeline([
               ('tfidf', TfidfVectorizer(stop_words=stop_words, ngram_range = (1, 2))),
               ('clf', CalibratedClassifierCV(OneVsRestClassifier(LinearSVC(), n_jobs=1))),
           ])

for category in categories:
    print('Emotion: {}'.format(category))
    # train the model using X_dtm & y
    SVC_pipeline.fit(X_train, train[category])
    # compute the testing accuracy
    prediction = SVC_pipeline.predict(X_test)
    print(' {}'.format(accuracy_score(test[category], prediction)))
# Out:
# Emotion: joy
#  0.9670912951167728
# Emotion: fear
#  0.7745930644019816
# Emotion: sadness
#  0.8152866242038217
# Emotion: anger
#  0.8627034677990092
# Emotion: surprise
#  0.9150743099787686
# Emotion: disgust
#  0.8563340410474168

# %%
#import pickle
#model = LinearSVC()
#filename = 'french_model.sav'
#pickle.dump(model, open(filename, 'wb'))

# %%
df_unseen = pd.read_csv('French_unseen.csv', encoding='latin-1')
df_unseen['word'] = df_unseen['word'].map(lambda com : clean_text(com))
df_unseen.head()
# Out:
#                                                    English  \
# 0  I am very happy
# 1  I'm really upset with you
# 2  I'm so frustrated with how it turned out
# 3  I love my daughter so much, she is the light of my life
# 4  I can't believe my car broke down, it's the worst!
#
#                                                                     word  joy  \
# 0  je suis très heureux                                                  NaN
# 1  je suis vraiment énervé contre toi                                    NaN
# 2  je suis tellement frustré de la façon dont cela  est avéré            NaN
# 3   aime tellement ma fille elle est la lumière de ma vie                NaN
# 4  je ne peux pas croire que ma voiture est tombée en panne  est la pire NaN
#
#    fear  sadness  anger  surprise  disgust
# 0 NaN   NaN      NaN    NaN       NaN
# 1 NaN   NaN      NaN    NaN       NaN
# 2 NaN   NaN      NaN    NaN       NaN
# 3 NaN   NaN      NaN    NaN       NaN
# 4 NaN   NaN      NaN    NaN       NaN

# %%
X_unseen = df_unseen.word

# %%
for category in categories:
    SVC_pipeline.fit(X_train, train[category])
    # compute the testing accuracy
    y_proba = SVC_pipeline.predict_proba(X_unseen)[:,1]
    df_unseen[category] = y_proba

# %%
df_unseen[0:10]
# Out:
#                                                                      English  \
# 0  I am very happy
# 1  I'm really upset with you
# 2  I'm so frustrated with how it turned out
# 3  I love my daughter so much, she is the light of my life
# 4  I can't believe my car broke down, it's the worst!
# 5  I hate croissants so much!
# 6  The flowers in the garden are so beautiful, every time I see them I smile
# 7  I am so worried about my interview tomorrow!
# 8  I think sea urchins are so disgusting, yuck!
# 9  I look forward to the day when Donald Trump is charged!
#
#                                                                         word  \
# 0  je suis très heureux
# 1  je suis vraiment énervé contre toi
# 2  je suis tellement frustré de la façon dont cela  est avéré
# 3   aime tellement ma fille elle est la lumière de ma vie
# 4  je ne peux pas croire que ma voiture est tombée en panne  est la pire
# 5  je déteste tellement les croissants
# 6  les fleurs du jardin sont si belles chaque fois que je les vois je souris
# 7  je suis tellement inquiet pour mon entretien de demain
# 8  je pense que les oursins sont si dégoûtants beurk
# 9   attends avec impatience le jour où donald trump sera mis en accusation
#
#         joy      fear   sadness     anger  surprise   disgust
# 0  0.060627  0.133283  0.126832  0.110711  0.088339  0.078149
# 1  0.032433  0.444769  0.228042  0.551586  0.062921  0.217069
# 2  0.031746  0.117290  0.096338  0.094265  0.059296  0.093165
# 3  0.206529  0.175877  0.110508  0.163776  0.043002  0.128620
# 4  0.030020  0.497187  0.519275  0.078834  0.052405  0.209900
# 5  0.036292  0.220410  0.168335  0.146812  0.079580  0.141054
# 6  0.081963  0.255728  0.079869  0.077828  0.051434  0.078800
# 7  0.032059  0.140489  0.112195  0.078139  0.062863  0.105776
# 8  0.033087  0.147342  0.117637  0.110972  0.065176  0.108782
# 9  0.029196  0.137689  0.074788  0.623556  0.066499  0.309654

# %%
## as expected, due to the limited nature of the dataset generalizability is poor
